# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from webdriver_manager.firefox import GeckoDriverManager
import pandas as pd
import requests
import json
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")

# %%
link = "https://medium.com/topic/data-science"
driver.get(link)
content = driver.page_source
soup = BeautifulSoup(content)

# %%
name = []
links =[]
summary =[]
skills=[]

# %% [markdown]
# # DS

# %%
for a in soup.findAll('section', attrs={'class':'gz ha aj ff s hb hc hd he hf'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------")

# %%
skills = "data_science"

# %%
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills})

# %%
df.to_csv('medium_ds.csv', index=False, encoding='utf-8')

# %%
data = pd.read_csv('medium_ds.csv')

# %%
data
# Out:
#                                          Article_Name  \
# 0   Can you really use ROI as your only metric in ...
# 1   Use this clustering method if you have many ou...
# 2     IPL Powerplay Score Prediction using AWS Lambda
# 3   Predicting Used Car Prices with Machine Learni...
# 4                         Grind Settings for Espresso
# 5                               Time Series in Python
# 6            Content Base Movie Recommendation Engine
# 7        Exploratory Data Analysis with Well Log Data
# 8   Exploring the Dataverse through a Virtual Real...
# 9   Actionable Insights from 4 Types of Data Analy...
# 10   Prescriptive Data Science 101: Types of Problems
# 11  Predicting Disneyland Wait Times through Popul...
# 12  Going for Gold: Predicting medal outcomes in t...
# 13  A Day in the Life of a Data Scientist in San F...
# 14  Useful Exploratory Data Analysis packages in P...
# 15  How to Publish your Data Science Project as a ...
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/data-science")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'class':'gz ha aj ff s hb hc hd he hf'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 35

# %%
skills = "data_science"

# %%
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills})

# %%
df.to_csv('medium_ds2.csv', index=False, encoding='utf-8')

# %%
data = pd.read_csv('medium_ds2.csv')

# %%
data
# Out:
#                                          Article_Name  \
# 0   Its AM-UN-DSEN, which every data driven compan...
# 1   How to create your own datasets for machine le...
# 2           Fun Data Analysis on My Baby’s Activities
# 3                 Are We Ready For Data Marketplaces?
# 4   Marketing Strategies for the Wholesale Market ...
# 5                             What is an ARIMA model?
# 6                  Design better charts in PowerPoint
# 7   International Travel Advisory and Restriction ...
# 8        How the science of data is transforming life
# 9       Crunching big data for good healthcare policy
# 10           Node customization for stunning networks
# 11  The Difference Between Classification and Regr...
# 12       A New Take on Analytical Workflow Management
# 13                 Analyzing ML Model using Dashboard
# 14        Deploy FastAPI on Azure with Github Actions
# 15  7 Cool Python Packages Kagglers Are Using With...
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/machine-learning")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'class':'gz ha aj ff s hb hc hd he hf'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 35

# %%
skills = "machine learning"

# %%
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_ml.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_ml.csv')

# %%
data
# Out:
#                                          Article_Name  \
# 0   Linear Regression For absolute beginners in 5 ...
# 1                   Tools for Efficient Deep Learning
# 2      The 3 levels of Natural Language Understanding
# 3   Review — Pelee: A Real-Time Object Detection S...
# 4   An Introduction to Linear Algebra for Deep Lea...
# 5   A list of research papers in Machine learning ...
# 6        WHAT IS GENERALIZATION IN MACHINE LEARNING ?
# 7            Node customization for stunning networks
# 8   The Difference Between Classification and Regr...
# 9        A New Take on Analytical Workflow Management
# 10                 Analyzing ML Model using Dashboard
# 11        Deploy FastAPI on Azure with Github Actions
# 12  7 Cool Python Packages Kagglers Are Using With...
# 13                        Mask Detection using YOLOv5
# 14    Data-Driven Approach for Schedule Optimizations
# 15                               Data Viz meets Death
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/programming")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight+200)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'class':'hj hk aj ff s hl hm hn ho hp'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 35

# %%
skills = "programming"

# %%
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_programming.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_programming.csv')
data
# Out:
#                                          Article_Name  \
# 0                   Automated Product Trials or Demos
# 1    Local Virtual Environments for your Python code.
# 2        Start a journey into the .NET Profiling APIs
# 3                          Testing HTTP servers in Go
# 4               Surviving the Pandemic as a Developer
# 5   Row-wise and column-wise operations in dplyr a...
# 6   The 1 Analogy Lasting Your Entire Coding Caree...
# 7             Learning to ‘Hack Android’ with picoCTF
# 8                 Version Control System - Git: Setup
# 9                    Enable Unity Ads in Mobile Games
# 10                      Deep Dive to Data Replication
# 11   The Great Fleece: Point & Click Movement, Part 3
# 12  The art of problem-solving in programming indu...
# 13  Developers Shouldn’t be Afraid of Deadlocks in...
# 14    Scoped Storage Support in Practo’s Android Apps
# 15                       How to Mock for Unit Testing
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/android-development")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight+200)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'gz ha aj ff s hb hc hd he hf'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 35

# %%
skills = "andriod development"

# %%
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_andriod.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_andriod.csv')
data
# Out:
#                                          Article_Name  \
# 0                       Android ViewBinding Migration
# 1               Large-screen UI in the Google I/O App
# 2               Actor based peaceful state management
# 3   What Matters Most to You? Here’s How to Find Out.
# 4   Video Recording and Playback App in React Nati...
# 5   Automated migration of your projects to Bazel ...
# 6   RecyclerView with different items and multiple...
# 7   Writing your profiler to analyze application p...
# 8   How to create a view programmatically with And...
# 9   Integration of Fingerprint and 3D Face Authent...
# 10                                 Now in Android #44
# 11                  Top Android MVI libraries in 2021
# 12                Introducing Navigation-Material 🧭🎨️
# 13                   Animations in Navigation Compose
# 14  Writing a Serverless Android app (ft. Huawei’s...
# 15                           State in Jetpack Compose
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/javascript")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight+200)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'hj hk aj ff s hl hm hn ho hp'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 35

# %%
skills = "javascript"
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_js.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_js.csv')
data
# Out:
#                                          Article_Name  \
# 0                JavaScript modules and browser cache
# 1                            Introduction to react js
# 2                              Roadmap to learn React
# 3      Pokémon Matching Cards: My ReactJS app project
# 4            The Real Way to Become a Good Programmer
# 5          Angular for everyone: Chapitre 2 Component
# 6   Sending HTML file in response, Serving static ...
# 7                     An Introduction to Redis Stream
# 8   How to Draw Stars with JavaScript and HTML5 Ca...
# 9   How to Use JavaScript and Node.js to Fight a D...
# 10  Building a Social Media App With Python 3 & Dj...
# 11  JavaScript Tutorial: Event Handling on a form ...
# 12             How to Export HTML Table to a CSV File
# 13  Develop an Appointment App with React and Tail...
# 14  How to Get the Closest Number to a Number Out ...
# 15    How to Unflatten a JSON Object with JavaScript?
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/ios-development")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight+200)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'hc hd aj ff s he hf hg hh hi'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 35

# %%
skills = "ios development"
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_ios.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_ios.csv')
data
# Out:
#                                          Article_Name  \
# 0   How to Call a Serverless Function Or Web API P...
# 1      Create a Shooting Game using Augmented Reality
# 2                   iOS — Record & Play an Audio Clip
# 3                           Swift Structs vs. Classes
# 4   Automatically translates views to use Auto Lay...
# 5                             Creating a CLI in Swift
# 6   Video Recording and Playback App in React Nati...
# 7   Introduction to Swift Programming: Hello World...
# 8                    iOS Custom Accessibility Actions
# 9                      Quick Win — Image Descriptions
# 10                              storyboard to swiftui
# 11  MVVM’s view model architecture with Reactive P...
# 12                   5 SwiftUI List Tricks for iOS 13
# 13  Build objects using block-based builder patter...
# 14                      Basics of Swift UI Animations
# 15                        An Updated SKLightNode Page
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/software-engineering")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight+200)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'gz ha aj ff s hb hc hd he hf'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 35

# %%
skills = "software engineering"
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_software.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_software.csv')
data
# Out:
#                                          Article_Name  \
# 0   SAFe vs Scrum discussions — a supposedly Skub ...
# 1     Why Sharding Gets Hard, and Why You Need Vitess
# 2             My path towards the PSM III certificate
# 3         What is Domain Driven Design (DDD) — Part 1
# 4   How to secure your Kubernetes control plane an...
# 5                      Decision, Dilemma, Risk Taking
# 6                                    Brief Primer CDK
# 7                                 You Ansible Killer!
# 8     The 3 Types of  Software Development Interviews
# 9   Why business-driven development must be above ...
# 10  Microservices with Orchestration and Choreography
# 11  The Best SaaS Tech Stack for your Startup Appl...
# 12     Video Game Localization Challenges & Solutions
# 13              How to Hire an Engineering Consultant
# 14                   How to Git a Branch: Work Safety
# 15  How MuleSoft Meets the Connectivity Needs of a...
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/blockchain")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight+200)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'hj hk aj ff s hl hm hn ho hp'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 34

# %%
skills = "blockchain"
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_blockchain.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_blockchain.csv')
data
# Out:
#                                          Article_Name  \
# 0                   Project Roadmap — Lido for Solana
# 1   Hedging Against Bad Weather with Cloud Dataset...
# 2   Meet DSCVR, a User-Controlled Decentralized So...
# 3                                Blockchain in Gaming
# 4     More on the Security Against Fee Sniping in RSK
# 5       How to send decentralized push notifications?
# 6   PAID Network is now live on BSC — Convert your...
# 7   Create a Slack Bot for Bitcoin Price Updates U...
# 8                           Battle of The Blockchains
# 9                Red States and Blue States vs Crypto
# 10    Can a blockchain be decentralized on the cloud?
# 11  Why a Simple Payments App is Integral to the S...
# 12    Immutability on the Blockchain; Myths or Facts?
# 13  Build a Decentralized Ticket Exchange Using th...
# 14  Project Watch: This Week’s Look At The Project...
# 15              Cryptocurrency: The Future of Finance
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/cryptocurrency")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight+200)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'gz ha aj ff s hb hc hd he hf'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 35

# %%
skills = "cryptocurrency"
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_cryptocurrency.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_cryptocurrency.csv')
data
# Out:
#                                          Article_Name  \
# 0   Cryptocurrency Guide: The Basics of Crypto Tra...
# 1   Riding Cardano Trend to $1.6 With Swings to Ac...
# 2   Why Billionaire’s Hate Bitcoin (And Other Cryp...
# 3   What is Efinity, the New NFT Blockchain from t...
# 4   ICy: A Decentralized Lending Protocol on the I...
# 5        Q: How to Make Crypto a Little Less Cryptic?
# 6   Bitcoin Is About To PumP Because Of This. Time...
# 7               Dashboards to track EIP-1559 ETH burn
# 8                      How to List NFT Art on OpenSea
# 9   What You Need To Know Before Buying Cryptocurr...
# 10  Towards Decentralized Protocols: Call for Coll...
# 11    That’s Why Buying More ADA, ETH, BTC, LINK, VET
# 12  Ethereum’s ‘London hard fork’ lifts the Crypto...
# 13                      How to Invest in Circle Stock
# 14  Why It’s Wrong To Think HODLing Hurts The Bloc...
# 15  You Can Belong to Future Tokens Where You‘ll O...
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/cybersecurity")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight+200)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'hc hd aj ff s he hf hg hh hi'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 35

# %%
skills = "cybersecurity"
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_cybersecurity.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_cybersecurity.csv')
data
# Out:
#                                          Article_Name  \
# 0                Leading with a cybersecurity mindset
# 1                  Using Sqlmap for Database Takeover
# 2   How to create your own VPN on Windows with Ope...
# 3                          Secure Coding Fundamentals
# 4                                   Understanding RSA
# 5                Your images compromise your security
# 6        Staking Migration Guide — How to Participate
# 7   Humanode: Strategic partnership with Republic ...
# 8   How to secure your Kubernetes control plane an...
# 9          Using THC Hydra To Brute Force Login Forms
# 10        How to detect runtime threats in Kubernetes
# 11                C and C++: Still Alive and Kicking!
# 12     I Watched a Training Video for Iranian Hackers
# 13                  Understanding ITP and its effects
# 14           Facebook escalates war on accountability
# 15                HTTP vs HTTPS—Why HTTP Is Not Safe?
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/psychology")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight+200)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'hj hk aj ff s hl hm hn ho hp'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 34

# %%
skills = "psychology"
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_psychology.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_psychology.csv')
data
# Out:
#                                          Article_Name  \
# 0     The Counselor as a Person and as a Professional
# 1                            The Secret to Resilience
# 2   Munchausen’s Syndrome by Internet (MbI or MBI)...
# 3     The Surprising Benefits of Talking to Strangers
# 4               The Scrambled Brain of the Narcissist
# 5                           What do we actually know?
# 6                   How Science Explains Ouija Boards
# 7                                      Force of Habit
# 8                   The Iowans Who Changed Psychology
# 9   Fear of Change: Reasons, Psychology, Tips & Qu...
# 10        “How Do I Find the Right Therapist for Me?”
# 11            Why I Won’t Deal With My Phobia of Mice
# 12  Why Therapy Shouldn’t Entirely Replace Punishment
# 13  How to Love Without Experiencing Attachment Su...
# 14            Jung’s Collective Unconscious Explained
# 15    The 5 Personality Patterns: Which One Fits You?
# ...

# %%
driver = webdriver.Firefox(executable_path="/home/ayush/Downloads/geckodriver")
driver.get("https://medium.com/topic/neuroscience")
driver.execute_script("window.scrollTo(0,document.body.scrollHeight+200)")
content = driver.page_source
soup = BeautifulSoup(content)
name = []
links =[]
summary =[]
skills=[]
for a in soup.findAll('section', attrs={'hj hk aj ff s hl hm hn ho hp'}):
    title = a.find('h3')
    name.append(title.get_text())
    location = a.find('a',href = True)
    links.append(location['href'])
    about = a.find('div',attrs={'class':'gj s'})
    try:
        summary.append(about.get_text())
        
    except:
        summary.append("--------") 
len(summary)
# Out:
# 34

# %%
skills = "neuroscience"
df = pd.DataFrame({'Article_Name':name,'Link':links,'About':summary,'Skills':skills}) 
df.to_csv('medium_neuroscience.csv', index=False, encoding='utf-8')
data = pd.read_csv('medium_neuroscience.csv')
data
# Out:
#                                          Article_Name  \
# 0               The Scrambled Brain of the Narcissist
# 1      5 Common Habits Sabotaging Your Nervous System
# 2   How Heroic Hearts Is Spearheading Psilocybin R...
# 3   The Surprising Health Benefits of Learning a S...
# 4       How the Brain is (or isn’t) “Just” a Computer
# 5   One way a change in our neurochemistry could a...
# 6   Balancing Our Neurotransmitters: Electrochemic...
# 7                             Understanding Addiction
# 8   Thrill-K: A Blueprint for The Next Generation ...
# 9                      Is I.T. All Between Your Ears?
# 10                                      Prosopagnosia
# 11  Glutamate as a cause of Neurodegenerative Dise...
# 12               The Right Brain has been Left Behind
# 13                                Multiply Determined
# 14  NS/ ‘Neuroprosthesis’ restores words to man wi...
# 15     DMT: The Spirit Molecule That Keeps Amazing Us
# ...
